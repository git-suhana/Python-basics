# %% [markdown]
# 1. Write a program that prints "Hello, How are You ? " on the console.

# %%
print("Hello,how are you?")
# Out:
# Hello,how are you?

# %% [markdown]
# 2. Write a program that take the user ‘s name and then prints a greeting
# message with their name.

# %%
name= str(input("enter your name"))
print("hello",name)
# Out:
# enter your namesuhana
# hello suhana

# %% [markdown]
# 3. Write a program that takes two numbers as input and prints their sum.

# %%
x= int(input("enter first number"))
y= int(input("enter second number"))
print(x+y)
# Out:
# enter first number2
# enter second number4
# 6

# %% [markdown]
# 4. Write a program that takes a string as input and prints its length.

# %%
x= str(input("enter a string"))
print(len(x))
# Out:
# enter a stringheklllo
# 7

# %% [markdown]
# 5. Write a program that takes a sentence and then prints the number of
# words in that sentence.

# %%
x= str(input("enter a sentence"))
print(len(x.split()))
# Out:
# enter a sentencehei how are to
# 4

# %% [markdown]
# 6. Write a program that takes a string as input and counts the number of
# uppercase letters in the string.

# %%
x= str(input("enter a string"))
count=0
for i in x:
  if i.isupper():
    count+=1
print(count)
# Out:
# enter a stringHAnayu
# 2

# %% [markdown]
# 7.Write a program that takes a sentence and then converts all the characters
# to uppercase.

# %%
x= str(input("enter a sentence"))
print(x.upper())
# Out:
# enter a sentencefiurnhf
# FIURNHF

# %% [markdown]
# 8. Write a program that takes a string as input and replaces all occurrences of
# the letter 'a' with the letter 'e'.

# %%
x= str(input("enter a string"))
y=x.replace("a","e")
print(y)
# Out:
# enter a stringsuhana
# suhene

# %% [markdown]
# 9. Create a program that checks if a given string is a palindrome.

# %%
x = str(input("enter a string"))
y = x[::-1]
if x==y:
  print("palindrome")
else:
  print("not palindrome")
# Out:
# enter a stringhindi
# not palindrome

# %% [markdown]
# 10. Create a program that checks if a substring is present in a given string.

# %%
x= str(input("enter a string"))
y= str(input("enter a substring"))
if y in x:
  print("present")
else:
  print("not present")
# Out:
# enter a stringhello suhanna
# enter a substringhello
# present

# %% [markdown]
# 11. Write a program that reverses the order of words in a given sentence.

# %%
x = str(input("enter a sentence"))
y = x.split()
print(" ".join(y[::-1]))
# Out:
# enter a sentencehi minu how are you
# you are how minu hi

# %% [markdown]
# 12. Write a program that finds the longest word in a given sentence.

# %%
x= str(input("enter a sentence"))
