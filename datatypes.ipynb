# %%
name ='arifa'
print(name)
# Out:
# arifa

# %%
type(name)
# Out:
# str

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
name='11'
print(type(name))           #inside quotes it will consider as a string
# Out:
# <class 'str'>

# %%
name = """aaaaaaabbbbbbbbccccccc
          dddddeeeeeefffffgggggg
          hhhhhhhhh"""                #for printing multiple lines
print(name)
# Out:
# aaaaaaabbbbbbbbccccccc
#           dddddeeeeeefffffgggggg
#           hhhhhhhhh

# %% [markdown]
# data type complex:

# %%
age=90+5j
print(age)
# Out:
# (90+5j)

# %%
print(type(age))
# Out:
# <class 'complex'>

# %%
print(age.real)
print(age.imag)
# Out:
# 90.0
# 5.0

# %% [markdown]
# sequence datatype - collection of data
# list, tuple, range
# Mapping datatype:
# dict(collection of data)
# Set type:
# set
# frozen set
# # **Boolean data type:**
# True - 1
# False - 0

# %%
print(True+True)
# Out:
# 2

# %%
x= True
print(type(x))
# Out:
# <class 'bool'>

# %%
print(True+False)
# Out:
# 1

# %% [markdown]
# NONE type

# %%
x= None
print(x)
print(type(x))
# Out:
# None
# <class 'NoneType'>
