# %% [markdown]
# Module in python:
# Module is a simple python file that contains collections of functions and global variables and with having a .py extension file. it is an executable file and to organize all the modules we have the concept called packages in python.
# examples:
# - datetime
# - regex
# - random
# - calendar

# %% [markdown]
# What is Package in Python?
#
# The package is a simple directory having collections of nodules. This directory contains Python modules and.
# The package is simply a namespace. The package also contains sub-packages inside it.
#
# Examples of Packages:
#
# Numpy
#
# Pandas

# %% [markdown]
# What is Library in Python
#
# The Library is having a collection of related functionality of codes that allows you to perform many tasks without writing your code.
# It is a reusable chunk of code that we can use by importing it into our program, we can just use it by importing that Library and
# calling the method of that Library with a periodi.). However, it is often assumed that while a package is a collection of nodules,
# a Library is a collection of packages.
#
# Examples of Libraries:
# Matplotlib
# Pytorch
# Pygame
# Seaborn
