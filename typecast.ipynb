# %% [markdown]
# to change the type of a variable
# eg:

# %%
age= 10
print(type(age))
# Out:
# <class 'int'>

# %%
a1 = str(age)
print(type(a1))
# Out:
# <class 'str'>

# %%
a2= float(age)
print(a2)
# Out:
# 10.0

# %%
a3= complex(age)
print (a3)
# Out:
# (10+0j)
