# %%
import pandas as pd

one = pd.DataFrame({'Name':['Alex','Amy','Allen','Alice','Ayoung','sarang'],'subject_id':['sub1','sub2','sub4','sub6','sub5','sub6'],'Marks_scored':[98,90,87,67,78,87]},index=[1,2,3,4,5,6])

two = pd.DataFrame({'Name':['Billy','Brian','Bran','Bryce','Betty'],'subject_id':['sub2','sub4','sub3','sub6','sub5'],'Marks_scored':[89,80,79,97,88]},index=[1,2,3,4,5])
three = pd.DataFrame({'Name':['Billy','Brian','Bran','Bryce','Betty'],'subject_id':['sub2','sub4','sub3','sub6','sub5'],'Marks_scored':[89,80,79,97,88],'roll no':[1,23,4,5,5]},index=[1,2,3,4,5])

# %%
print(one)
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            67
# 5  Ayoung       sub5            78
# 6  sarang       sub6            87

# %%
print(two)
# Out:
#     Name subject_id  Marks_scored
# 1  Billy       sub2            89
# 2  Brian       sub4            80
# 3   Bran       sub3            79
# 4  Bryce       sub6            97
# 5  Betty       sub5            88

# %%
print(three)
# Out:
#     Name subject_id  Marks_scored  roll no
# 1  Billy       sub2            89        1
# 2  Brian       sub4            80       23
# 3   Bran       sub3            79        4
# 4  Bryce       sub6            97        5
# 5  Betty       sub5            88        5

# %%
df= pd.concat([one,two])
df
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            67
# 5  Ayoung       sub5            78
# 6  sarang       sub6            87
# 1   Billy       sub2            89
# 2   Brian       sub4            80
# 3    Bran       sub3            79
# 4   Bryce       sub6            97
# 5   Betty       sub5            88

# %%
df= pd.concat([one,three])
df
# Out:
#      Name subject_id  Marks_scored  roll no
# 1    Alex       sub1            98      NaN
# 2     Amy       sub2            90      NaN
# 3   Allen       sub4            87      NaN
# 4   Alice       sub6            67      NaN
# 5  Ayoung       sub5            78      NaN
# 6  sarang       sub6            87      NaN
# 1   Billy       sub2            89      1.0
# 2   Brian       sub4            80     23.0
# 3    Bran       sub3            79      4.0
# 4   Bryce       sub6            97      5.0
# 5   Betty       sub5            88      5.0

# %%
df= pd.concat([one,three],keys=['one','two'])
df
# Out:
#          Name subject_id  Marks_scored  roll no
# one 1    Alex       sub1            98      NaN
#     2     Amy       sub2            90      NaN
#     3   Allen       sub4            87      NaN
#     4   Alice       sub6            67      NaN
#     5  Ayoung       sub5            78      NaN
#     6  sarang       sub6            87      NaN
# two 1   Billy       sub2            89      1.0
#     2   Brian       sub4            80     23.0
#     3    Bran       sub3            79      4.0
#     4   Bryce       sub6            97      5.0
#     5   Betty       sub5            88      5.0

# %%
df= pd.concat([one,three],keys=['one','two'],ignore_index=True)
df
# Out:
#       Name subject_id  Marks_scored  roll no
# 0     Alex       sub1            98      NaN
# 1      Amy       sub2            90      NaN
# 2    Allen       sub4            87      NaN
# 3    Alice       sub6            67      NaN
# 4   Ayoung       sub5            78      NaN
# 5   sarang       sub6            87      NaN
# 6    Billy       sub2            89      1.0
# 7    Brian       sub4            80     23.0
# 8     Bran       sub3            79      4.0
# 9    Bryce       sub6            97      5.0
# 10   Betty       sub5            88      5.0

# %%
df=pd.concat([one,three],keys=['one','two'],ignore_index=True,axis=1)
df
# Out:
#         0     1   2      3     4     5     6
# 1    Alex  sub1  98  Billy  sub2  89.0   1.0
# 2     Amy  sub2  90  Brian  sub4  80.0  23.0
# 3   Allen  sub4  87   Bran  sub3  79.0   4.0
# 4   Alice  sub6  67  Bryce  sub6  97.0   5.0
# 5  Ayoung  sub5  78  Betty  sub5  88.0   5.0
# 6  sarang  sub6  87    NaN   NaN   NaN   NaN

# %%
import pandas as pd


two = pd.DataFrame({'id':[1,2,3,4,5],'Name':['Billy','Brian','Bran','Bryce','Betty'],'subject_id':['sub2','sub4','sub3','sub6','sub5'],'Marks_scored':[89,80,79,97,88]},index=[1,2,3,4,5])

three = pd.DataFrame({'id':[1,2,3,4,5],'Name':['Billy','Brian','Bran','Bryce','Betty'],'subject_id':['sub2','sub4','sub3','sub6','sub5'],'Marks_scored':[89,80,79,97,88],'roll no':[1,23,4,5,5]},index=[1,2,3,4,5])

# %%
print(two)
# Out:
#    id   Name subject_id  Marks_scored
# 1   1  Billy       sub2            89
# 2   2  Brian       sub4            80
# 3   3   Bran       sub3            79
# 4   4  Bryce       sub6            97
# 5   5  Betty       sub5            88

# %%
print(three)
# Out:
#    id   Name subject_id  Marks_scored  roll no
# 1   1  Billy       sub2            89        1
# 2   2  Brian       sub4            80       23
# 3   3   Bran       sub3            79        4
# 4   4  Bryce       sub6            97        5
# 5   5  Betty       sub5            88        5

# %%
df=pd.merge(two,three)
df
# Out:
#    id   Name subject_id  Marks_scored  roll no
# 0   1  Billy       sub2            89        1
# 1   2  Brian       sub4            80       23
# 2   3   Bran       sub3            79        4
# 3   4  Bryce       sub6            97        5
# 4   5  Betty       sub5            88        5

# %%
df=pd.merge(two,three,on='id')
df
# Out:
#    id Name_x subject_id_x  Marks_scored_x Name_y subject_id_y  Marks_scored_y  \
# 0   1  Billy         sub2              89  Billy         sub2              89
# 1   2  Brian         sub4              80  Brian         sub4              80
# 2   3   Bran         sub3              79   Bran         sub3              79
# 3   4  Bryce         sub6              97  Bryce         sub6              97
# 4   5  Betty         sub5              88  Betty         sub5              88
#
#    roll no
# 0        1
# 1       23
# 2        4
# 3        5
# 4        5

# %%
df=pd.merge(two,three,on=['id','subject_id'])
df
# Out:
#    id Name_x subject_id  Marks_scored_x Name_y  Marks_scored_y  roll no
# 0   1  Billy       sub2              89  Billy              89        1
# 1   2  Brian       sub4              80  Brian              80       23
# 2   3   Bran       sub3              79   Bran              79        4
# 3   4  Bryce       sub6              97  Bryce              97        5
# 4   5  Betty       sub5              88  Betty              88        5

# %%
df=pd.merge(two,three,on=['id','subject_id'],how='right')
df
# Out:
#    id Name_x subject_id  Marks_scored_x Name_y  Marks_scored_y  roll no
# 0   1  Billy       sub2              89  Billy              89        1
# 1   2  Brian       sub4              80  Brian              80       23
# 2   3   Bran       sub3              79   Bran              79        4
# 3   4  Bryce       sub6              97  Bryce              97        5
# 4   5  Betty       sub5              88  Betty              88        5

# %%
df=pd.merge(two,three,on=['id','subject_id'],how='left')
df
# Out:
#    id Name_x subject_id  Marks_scored_x Name_y  Marks_scored_y  roll no
# 0   1  Billy       sub2              89  Billy              89        1
# 1   2  Brian       sub4              80  Brian              80       23
# 2   3   Bran       sub3              79   Bran              79        4
# 3   4  Bryce       sub6              97  Bryce              97        5
# 4   5  Betty       sub5              88  Betty              88        5

# %%
df=pd.merge(two,three,on='id',how='outer')
df
# Out:
#    id Name_x subject_id_x  Marks_scored_x Name_y subject_id_y  Marks_scored_y  \
# 0   1  Billy         sub2              89  Billy         sub2              89
# 1   2  Brian         sub4              80  Brian         sub4              80
# 2   3   Bran         sub3              79   Bran         sub3              79
# 3   4  Bryce         sub6              97  Bryce         sub6              97
# 4   5  Betty         sub5              88  Betty         sub5              88
#
#    roll no
# 0        1
# 1       23
# 2        4
# 3        5
# 4        5

# %%
df=pd.merge(two,three,on='id',how='inner')
df
# Out:
#    id Name_x subject_id_x  Marks_scored_x Name_y subject_id_y  Marks_scored_y  \
# 0   1  Billy         sub2              89  Billy         sub2              89
# 1   2  Brian         sub4              80  Brian         sub4              80
# 2   3   Bran         sub3              79   Bran         sub3              79
# 3   4  Bryce         sub6              97  Bryce         sub6              97
# 4   5  Betty         sub5              88  Betty         sub5              88
#
#    roll no
# 0        1
# 1       23
# 2        4
# 3        5
# 4        5

# %%
import pandas as pd
import numpy as np
data1 = {'Name':['raju','ramu','sarang','raju','ramu','sarang','raju','ramu','sarang'],'chem':[40,60,40,40,60,40,40,60,40],'maths':[40,60,40,40,60,40,40,60,40],'phy':[40,60,40,40,60,40,40,60,40]}

df= pd.DataFrame(data1)

df['bio'] = [60,48,50,60,48,50,60,48,50]

df['total_mark'] = df['chem']+df['maths']+df['phy']+df['bio']
print(df)
df1= df.iloc[0:4,0:5]
df1
# Out:
#      Name  chem  maths  phy  bio  total_mark
# 0    raju    40     40   40   60         180
# 1    ramu    60     60   60   48         228
# 2  sarang    40     40   40   50         170
# 3    raju    40     40   40   60         180
# 4    ramu    60     60   60   48         228
# 5  sarang    40     40   40   50         170
# 6    raju    40     40   40   60         180
# 7    ramu    60     60   60   48         228
# 8  sarang    40     40   40   50         170
#      Name  chem  maths  phy  bio
# 0    raju    40     40   40   60
# 1    ramu    60     60   60   48
# 2  sarang    40     40   40   50
# 3    raju    40     40   40   60

# %%
import pandas as pd
import numpy as np
data1 = {'Name':['raju','ramu','sarang','raju','ramu','sarang','raju','ramu','sarang'],'chem':[40,60,40,40,60,40,40,60,40],'maths':[40,60,40,40,60,40,40,60,40],'phy':[40,60,40,40,60,40,40,60,40]}

df= pd.DataFrame(data1)

df['bio'] = [60,48,50,60,48,50,60,48,50]

df['total_mark'] = df['chem']+df['maths']+df['phy']+df['bio']
df1= df.loc[0:4,'Name':'phy']
df1
# Out:
#      Name  chem  maths  phy
# 0    raju    40     40   40
# 1    ramu    60     60   60
# 2  sarang    40     40   40
# 3    raju    40     40   40
# 4    ramu    60     60   60

# %%
import pandas as pd
import numpy as np
data1 = {'Name':['raju','ramu','sarang','raju','ramu','sarang','raju','ramu','sarang'],'chem':[40,60,40,40,60,40,40,60,40],'maths':[40,60,40,40,60,40,40,60,40],'phy':[40,60,40,40,60,40,40,60,40]}

df= pd.DataFrame(data1)

df['bio'] = [60,48,50,60,48,50,60,48,50]

df['total_mark'] = df['chem']+df['maths']+df['phy']+df['bio']
print(df)
df1=df.at[0,'phy']
df1
# Out:
#      Name  chem  maths  phy  bio  total_mark
# 0    raju    40     40   40   60         180
# 1    ramu    60     60   60   48         228
# 2  sarang    40     40   40   50         170
# 3    raju    40     40   40   60         180
# 4    ramu    60     60   60   48         228
# 5  sarang    40     40   40   50         170
# 6    raju    40     40   40   60         180
# 7    ramu    60     60   60   48         228
# 8  sarang    40     40   40   50         170
# 40

# %%
import pandas as pd
import numpy as np
data1 = {'Name':['raju','ramu','sarang','raju','ramu','sarang','raju','ramu','sarang'],'chem':[40,60,40,40,60,40,40,60,40],'maths':[40,60,40,40,60,40,40,60,40],'phy':[40,60,40,40,60,40,40,60,40]}

df= pd.DataFrame(data1)

df['bio'] = [60,48,50,60,48,50,60,48,50]

df['total_mark'] = df['chem']+df['maths']+df['phy']+df['bio']
print(df)
df1= df.iat[0,3]
df1
# Out:
#      Name  chem  maths  phy  bio  total_mark
# 0    raju    40     40   40   60         180
# 1    ramu    60     60   60   48         228
# 2  sarang    40     40   40   50         170
# 3    raju    40     40   40   60         180
# 4    ramu    60     60   60   48         228
# 5  sarang    40     40   40   50         170
# 6    raju    40     40   40   60         180
# 7    ramu    60     60   60   48         228
# 8  sarang    40     40   40   50         170
# 40

# %%
import pandas as pd
import numpy as np
data = [[40,60,40,40,60,70],[60,30,90,40,60,40],[40,50,1240,60,40]]
df= pd.DataFrame(data)
df
def adder(a,b):
  return a+b
print(df)
df1= df.pipe(adder,2)
print(df1)
# Out:
#     0   1     2   3   4     5
# 0  40  60    40  40  60  70.0
# 1  60  30    90  40  60  40.0
# 2  40  50  1240  60  40   NaN
#     0   1     2   3   4     5
# 0  42  62    42  42  62  72.0
# 1  62  32    92  42  62  42.0
# 2  42  52  1242  62  42   NaN

# %%
import pandas as pd
import numpy as np
data = [[40,60,40,40,60,70],[60,30,90,40,60,40],[40,50,1240,60,40]]
df= pd.DataFrame(data)
def adder(a):
  return a**2
print(df)
df1= df.apply(adder,axis=0)
print(df1)
# Out:
#     0   1     2   3   4     5
# 0  40  60    40  40  60  70.0
# 1  60  30    90  40  60  40.0
# 2  40  50  1240  60  40   NaN
#       0     1        2     3     4       5
# 0  1600  3600     1600  1600  3600  4900.0
# 1  3600   900     8100  1600  3600  1600.0
# 2  1600  2500  1537600  3600  1600     NaN

# %%
import pandas as pd
import numpy as np
data = [[40,60,40,40,60,70],[60,30,90,40,60,40],[40,50,1240,60,40]]
df= pd.DataFrame(data)
def adder(a):
  return a**2
print(df)
df1= df.apply(adder,axis=1)
print(df1)
# Out:
#     0   1     2   3   4     5
# 0  40  60    40  40  60  70.0
# 1  60  30    90  40  60  40.0
# 2  40  50  1240  60  40   NaN
#         0       1          2       3       4       5
# 0  1600.0  3600.0     1600.0  1600.0  3600.0  4900.0
# 1  3600.0   900.0     8100.0  1600.0  3600.0  1600.0
# 2  1600.0  2500.0  1537600.0  3600.0  1600.0     NaN

# %%
import pandas as pd
import numpy as np
data = [[40,60,40,40,60,70],[60,30,90,40,60,40],[40,50,1240,60,40]]
df= pd.DataFrame(data)
def adder(a):
  return a**2
print(df)
df1= df.apply(np.mean,axis=1)
print(df1)
# Out:
#     0   1     2   3   4     5
# 0  40  60    40  40  60  70.0
# 1  60  30    90  40  60  40.0
# 2  40  50  1240  60  40   NaN
# 0     51.666667
# 1     53.333333
# 2    286.000000
# dtype: float64

# %%
import pandas as pd
import numpy as np
data = [[40,60,40,40,60,70],[60,30,90,40,60,40],[40,50,1240,60,40]]
df= pd.DataFrame(data)
def adder(a):
  return a**2
print(df)
df1= df.apply(np.mean,axis=0)
print(df1)
# Out:
#     0   1     2   3   4     5
# 0  40  60    40  40  60  70.0
# 1  60  30    90  40  60  40.0
# 2  40  50  1240  60  40   NaN
# 0     46.666667
# 1     46.666667
# 2    456.666667
# 3     46.666667
# 4     53.333333
# 5     55.000000
# dtype: float64

# %%
import pandas as pd
import numpy as np
data = [[40,60,40,40,60,70],[60,30,90,40,60,40],[40,50,1240,60,40]]
df= pd.DataFrame(data)
def adder(a):
  return a+b
print(df)
df1= df.apply(np.sum,axis=0)
print(df1)
# Out:
#     0   1     2   3   4     5
# 0  40  60    40  40  60  70.0
# 1  60  30    90  40  60  40.0
# 2  40  50  1240  60  40   NaN
# 0     140.0
# 1     140.0
# 2    1370.0
# 3     140.0
# 4     160.0
# 5     110.0
# dtype: float64

# %%
import pandas as pd
import numpy as np
data = [[40,60,40,40,60,70],[60,30,90,40,60,40],[40,50,1240,60,40]]
df= pd.DataFrame(data)
def adder(a):
  return a+b
print(df)
df1= df.apply(np.sum,axis=1)
print(df1)
# Out:
#     0   1     2   3   4     5
# 0  40  60    40  40  60  70.0
# 1  60  30    90  40  60  40.0
# 2  40  50  1240  60  40   NaN
# 0     310.0
# 1     320.0
# 2    1430.0
# dtype: float64

# %%
import pandas as pd
import numpy as np
data = [[40,60,40,40,60,70],[60,30,90,40,60,40],[40,50,1240,60,40]]
df= pd.DataFrame(data)
def adder(a):
  return a.sum()
print(df)
df1=df.apply(adder,axis=0)
print(df1)
# Out:
#     0   1     2   3   4     5
# 0  40  60    40  40  60  70.0
# 1  60  30    90  40  60  40.0
# 2  40  50  1240  60  40   NaN
# 0     140.0
# 1     140.0
# 2    1370.0
# 3     140.0
# 4     160.0
# 5     110.0
# dtype: float64

# %%
import pandas as pd
import numpy as np
data = [[40,60,40,40,60,70],[60,30,90,40,60,40],[40,50,1240,60,40]]
df= pd.DataFrame(data)
def adder(a):
  return a.sum()
print(df)
df1=df.apply(adder,axis=1)
print(df1)
# Out:
#     0   1     2   3   4     5
# 0  40  60    40  40  60  70.0
# 1  60  30    90  40  60  40.0
# 2  40  50  1240  60  40   NaN
# 0     310.0
# 1     320.0
# 2    1430.0
# dtype: float64

# %%
import pandas as pd
import numpy as np
data = [[40,60,40,40,60,70],[60,30,90,40,60,40],[40,50,1240,60,40]]
df= pd.DataFrame(data)
def adder(a):
  return a.sum()
print(df)
df1=df.apply(lambda x:x.max()-x.min(),axis=0)
print(df1)
# Out:
#     0   1     2   3   4     5
# 0  40  60    40  40  60  70.0
# 1  60  30    90  40  60  40.0
# 2  40  50  1240  60  40   NaN
# 0      20.0
# 1      30.0
# 2    1200.0
# 3      20.0
# 4      20.0
# 5      30.0
# dtype: float64

# %%
import pandas as pd
import numpy as np
data = [[40,60,40,40,60,70],[60,30,90,40,60,40],[40,50,1240,60,40]]
df= pd.DataFrame(data)
def adder(a):
  return a.sum()
print(df)
df1=df.apply(lambda x:x.max()-x.min(),axis=1)
print(df1)
# Out:
#     0   1     2   3   4     5
# 0  40  60    40  40  60  70.0
# 1  60  30    90  40  60  40.0
# 2  40  50  1240  60  40   NaN
# 0      30.0
# 1      60.0
# 2    1200.0
# dtype: float64
