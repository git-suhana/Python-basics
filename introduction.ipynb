# %% [markdown]
# * Python is a popular programming language
# python can connect to database system, it can read and modify files
# python can be used to handle big data and perform complex mathematical operations
# python is platform independant with simple syntax.

# %%
print("suhana")
# Out:
# suhana

# %%
b=10
print(b)
a= "sh"
print(a)
# Out:
# 10
# sh

# %% [markdown]
# Python Indentation
# Indentation refers to the spaces at the beginning of code line
# where in other programming language indentation is for readability only, the indentation in python is very important
# python uses indentation to indicate a block of code.

# %% [markdown]
# comments starts with a # and python will render the rest of the line as comment.
# it can be used to prevent the execution when testing code
# it makes code more readable

# %% [markdown]
# multi line comments:
# use multiline string(triple quotes) and place the comments inside it.

# %%
a= "inn"

print(type(a))
# Out:
# <class 'str'>

# %% [markdown]
# python follows automatic memory allocation

# %% [markdown]
# casting:
# to specify the datatype of a variable
# string variables can be declared in single or double quotes.
# Python is case sensitive

# %% [markdown]
# variable name can be short or long, but it must start with an alphabet or underscore, not with a number. variable name can contain alphanumeric characters(a-z, 0-9 ) and underscore.

# %% [markdown]
# datatypes in python
# text type- str
# numeric type-
# int
# float
# eg:5.1
# complex:
# eg:a= 90+5j
# print(a.real)
# =90.0
# print(a.imag)
# =5
